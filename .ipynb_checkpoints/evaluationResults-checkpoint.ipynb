# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import importlib

# %%
df_synthetic_results = pd.read_csv('results_syntheticData.csv')
df_synthetic_results
# Out:
#                                            method       ATE  \
# 0                                     Causal Tree  2.000000
# 1                                    cforest_cmse  2.000000
# 2                              cforest_cmse_p=0.5  2.000000
# 3                         cforest_cmse_p=0.5_md=3  2.000000
# 4                                   cforest_ttest  2.000000
# 5                                          IPW LR  2.000000
# 6                                       Double ML  1.994487
# 7                               Linear Regression  2.000000
# 8                                    S-Learner LR  2.000000
# 9                                   XGBTRegressor  2.000000
# 10                             BaseTRegressor XGB  2.000000
# 11                              BaseTRegressor LR  2.000000
# 12                             BaseXRegressor XGB  2.000000
# 13                              BaseXRegressor LR  2.000000
# 14  BaseXRegressor XGB (without propensity score)  2.000000
# ...

# %%
true_value = 2
predicted_values = df_synthetic_results['ATE']

# %%
#importlib.reload(evaluation_metrics)
import evaluation_metrics
mse, mae, rmse, bias, enormse = evaluation_metrics.evaluation_metrics(true_value, predicted_values)

# %%
print("Mean Squared Error (MSE):", mse)
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
print("Bias:", bias)
print("ENoRMSE:", enormse)
# Out:
# Mean Squared Error (MSE): 0.7107770456067102
# Mean Absolute Error (MAE): 0.40820575927066494
# Root Mean Squared Error (RMSE): 0.843075942965229
# Bias: 0.40820575927066394
# ENoRMSE: 0.4215379714826145
